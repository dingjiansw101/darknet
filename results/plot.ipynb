# %%
import pandas as pd
import re
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
exper1_x = np.loadtxt('exper1/pr.txt')
exper2_x  = np.loadtxt('exper2/pr.txt')
exper3_x = np.loadtxt('exper3/pr.txt')
plt.plot(exper1_x[:,1],exper1_x[:,0], 'g-x', 
        exper2_x[:,1],exper2_x[:,0], 'b-',
        exper3_x[:,1],exper3_x[:,0], 'r-')


plt.xlabel('recall')
plt.ylabel('precision')
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.show()
#plt.scatter(x[:,1],x[:,0], c='red')
